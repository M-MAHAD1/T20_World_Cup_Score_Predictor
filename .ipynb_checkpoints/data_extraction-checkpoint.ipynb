# %%
# numpy, pandas, aur yaml libraries ko import kiya gaya hai.
# os file system ke sath kaam karne ke liye hai (jaise folder ke files read karna).
# tqdm progress bar show karta hai loop ke andar jab kaam ho raha ho.
import numpy as np
import pandas as pd
from yaml import safe_load
import os
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# data folder ke andar jitne files hain, unka poora path (data/file_name) banaya gaya hai.
# Har file ka path filenames list mein store ho raha hai.
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[0:5]
# Out:
# ['data\\1001349.yaml',
#  'data\\1001351.yaml',
#  'data\\1001353.yaml',
#  'data\\1004729.yaml',
#  'data\\1007655.yaml']

# %%
# Yeh ek khaali list banayi gayi hai jismein har file ka data (as DataFrame) store kiya jayega.
df_list = []
counter = 1

for file in tqdm(filenames):
    with open(file, 'r') as f:
        try:
            data = safe_load(f)
        except Exception as e:
            print(f"YAML load error in file {file}: {e}")
            continue

    if data is None:
        print(f"Skipping empty or invalid file: {file}")
        continue

    if isinstance(data, (dict, list)):
        try:
            df = pd.json_normalize(data)
            df['match_id'] = counter
            df_list.append(df)
            counter += 1
        except Exception as e:
            print(f"Error normalizing file {file}: {e}")
    else:
        print(f"Unsupported data type in file {file}: {type(data)}")

# Concatenate all DataFrames
final_df = pd.concat(df_list, ignore_index=True)
# Out:
# 100%|██████████| 1433/1433 [04:55<00:00,  4.85it/s]
# Unsupported data type in file data\README.txt: <class 'str'>

# %%
backup = final_df.copy()

# %%
final_df.head(3)
# Out:
#                                              innings  meta.data_version  \
# 0  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 1  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2  [{'1st innings': {'team': 'Australia', 'delive...                0.9
#
#   meta.created  meta.revision    info.dates info.gender info.match_type  \
# 0   2017-02-18              2  [2017-02-17]        male             T20
# 1   2017-02-19              2  [2017-02-19]        male             T20
# 2   2017-02-23              1  [2017-02-22]        male             T20
#
#    info.outcome.by.wickets info.outcome.winner  info.overs  ...  \
# 0                      5.0           Sri Lanka          20  ...
# 1                      2.0           Sri Lanka          20  ...
# 2                      NaN           Australia          20  ...
#
#   info.outcome.by.runs info.match_type_number info.neutral_venue  \
# ...

# %%
final_df.shape
# Out:
# (1432, 28)

# %%
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.bowl_out',
    'info.bowl_out',
    'info.supersubs.South Africa',
    'info.supersubs.New Zealand',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
final_df.shape
# Out:
# (1432, 14)

# %%
final_df['info.gender'].value_counts()
# Out:
# info.gender
# male      966
# female    466
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.gender'] == 'male']
final_df.drop(columns=['info.gender'],inplace=True)
final_df
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 1427  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 1428  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 1429  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 1430  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 1431  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.match_type info.outcome.winner  info.overs info.player_of_match  \
# ...

# %%
final_df.shape
# Out:
# (966, 13)

# %%
final_df['info.match_type'].value_counts()
# Out:
# info.match_type
# T20    966
# Name: count, dtype: int64

# %%
final_df['info.overs'].value_counts()
# Out:
# info.overs
# 20    963
# 50      3
# Name: count, dtype: int64

# %%
final_df = final_df[final_df['info.overs'] == 20]
final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
final_df
# Out:
# C:\Users\MAHAD\AppData\Local\Temp\ipykernel_2024\3157072726.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=['info.overs','info.match_type'],inplace=True)
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 1427  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# ...

# %%
# Importing pickle module for saving Python objects
# This line saves the processed DataFrame 'output' into a file named 'dataset_level2.pkl'
# 'wb' means write in binary mode, which is required by pickle
# This allows you to reuse the preprocessed data without running the preprocessing code again
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
matches = pickle.load(open('dataset_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.5: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {1.1: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
# ...

# %%
count = 1
delivery_df = pd.DataFrame()

for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count += 1
        continue
    count += 1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []

    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')

    loop_df = pd.DataFrame({
        'match_id': match_id,
        'teams': teams,
        'batting_team': batting_team,
        'ball': ball_of_match,
        'batsman': batsman,
        'bowler': bowler,
        'runs': runs,
        'player_dismissed': player_of_dismissed,
        'city': city,
        'venue': venue
    })

    # ✅ Corrected line
    delivery_df = pd.concat([delivery_df, loop_df], ignore_index=True)

# %%
delivery_df
# Out:
#         match_id                   teams batting_team  ball          batsman  \
# 0              2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1              2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2              2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3              2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4              2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ...          ...                     ...          ...   ...              ...
# 115320       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 115321       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 115322       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 115323       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 115324       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
# ...

# %%
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowl,axis=1)

# %%
delivery_df
# Out:
#         match_id                   teams batting_team  ball          batsman  \
# 0              2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1              2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2              2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3              2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4              2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ...          ...                     ...          ...   ...              ...
# 115320       964  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 115321       964  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 115322       964  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 115323       964  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 115324       964  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania'],
#       dtype=object)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#         match_id batting_team  ball          batsman      bowler  runs  \
# 0              2    Australia   0.1         AJ Finch  SL Malinga     0
# 1              2    Australia   0.2         AJ Finch  SL Malinga     0
# 2              2    Australia   0.3         AJ Finch  SL Malinga     1
# 3              2    Australia   0.4        M Klinger  SL Malinga     2
# 4              2    Australia   0.5        M Klinger  SL Malinga     0
# ...          ...          ...   ...              ...         ...   ...
# 115320       964    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 115321       964    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 115322       964    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 115323       964    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 115324       964    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#        player_dismissed     city                     venue bowling_team
# ...

# %%
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#            city                     venue
# 0           NaN  Melbourne Cricket Ground
# ...

# %%
pickle.dump(output,open('dataset_level2.pkl','wb'))

# %%
output[output['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
x = np.where(output['city'].isnull(), output['venue'].str.split().apply(lambda x:x[0]), output['city'])

# %%
output['city'] = x
# Out:
# C:\Users\MAHAD\AppData\Local\Temp\ipykernel_2024\2208188131.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['city'] = x

# %%
output.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
output.drop(columns=['venue'],inplace=True)
# Out:
# C:\Users\MAHAD\AppData\Local\Temp\ipykernel_2024\2962604362.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output.drop(columns=['venue'],inplace=True)

# %%
output
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2    Australia    Sri Lanka   0.1     0                0
# 1              2    Australia    Sri Lanka   0.2     0                0
# 2              2    Australia    Sri Lanka   0.3     1                0
# 3              2    Australia    Sri Lanka   0.4     2                0
# 4              2    Australia    Sri Lanka   0.5     0                0
# ...          ...          ...          ...   ...   ...              ...
# 115320       964    Sri Lanka    Australia  19.3     1                0
# 115321       964    Sri Lanka    Australia  19.4     0                0
# 115322       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 115323       964    Sri Lanka    Australia  19.6     2                0
# 115324       964    Sri Lanka    Australia  19.7     1                0
#
#              city
# 0       Melbourne
# 1       Melbourne
# 2       Melbourne
# 3       Melbourne
# ...

# %%
total_df = output.groupby('match_id').sum()['runs'].reset_index()
output = output.merge(total_df,on='match_id')

# %%
output
# Out:
#        match_id batting_team bowling_team  ball  runs_x player_dismissed  \
# 0             2    Australia    Sri Lanka   0.1       0                0
# 1             2    Australia    Sri Lanka   0.2       0                0
# 2             2    Australia    Sri Lanka   0.3       1                0
# 3             2    Australia    Sri Lanka   0.4       2                0
# 4             2    Australia    Sri Lanka   0.5       0                0
# ...         ...          ...          ...   ...     ...              ...
# 63883       964    Sri Lanka    Australia  19.3       1                0
# 63884       964    Sri Lanka    Australia  19.4       0                0
# 63885       964    Sri Lanka    Australia  19.5       0      DM de Silva
# 63886       964    Sri Lanka    Australia  19.6       2                0
# 63887       964    Sri Lanka    Australia  19.7       1                0
#
#             city  runs_y
# 0      Melbourne     168
# 1      Melbourne     168
# ...

# %%
# Ensure numeric runs_x
output['runs_x'] = pd.to_numeric(output['runs_x'], errors='coerce').fillna(0)

# Compute current score by match
output['current_score'] = output.groupby('match_id')['runs_x'].cumsum()

# Extract over and ball number
output['ball'] = output['ball'].astype(str)  # ensure it's string
output['over'] = output['ball'].apply(lambda x: x.split(".")[0])
output['ball_no'] = output['ball'].apply(lambda x: x.split(".")[1])

# Compute total balls bowled
output['balls_bowled'] = (output['over'].astype(int) * 6) + output['ball_no'].astype(int)

# Compute CRR (current run rate)
output['crr'] = round((output['current_score'] * 6) / output['balls_bowled'], 2)

# Clean and process dismissals
output['player_dismissed'] = output['player_dismissed'].apply(lambda x: 0 if x == '0' else 1)
output['player_dismissed'] = output['player_dismissed'].astype(int)
output['player_dismissed'] = output.groupby('match_id')['player_dismissed'].cumsum()

# Calculate wickets left
output['wickets_left'] = 10 - output['player_dismissed']

# Final selected columns
final_df = output[['match_id', 'batting_team', 'bowling_team', 'runs_x', 'current_score',
                   'balls_bowled', 'wickets_left', 'crr', 'city', 'runs_y']]

# Show the final dataframe
final_df
# Out:
#        match_id batting_team bowling_team  runs_x  current_score  \
# 0             2    Australia    Sri Lanka       0              0
# 1             2    Australia    Sri Lanka       0              0
# 2             2    Australia    Sri Lanka       1              1
# 3             2    Australia    Sri Lanka       2              3
# 4             2    Australia    Sri Lanka       0              3
# ...         ...          ...          ...     ...            ...
# 63883       964    Sri Lanka    Australia       1            125
# 63884       964    Sri Lanka    Australia       0            125
# 63885       964    Sri Lanka    Australia       0            125
# 63886       964    Sri Lanka    Australia       2            127
# 63887       964    Sri Lanka    Australia       1            128
#
#        balls_bowled  wickets_left   crr       city  runs_y
# 0                 1            10  0.00  Melbourne     168
# 1                 2            10  0.00  Melbourne     168
# ...

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df['balls_left'] = 120 - final_df['balls_bowled']
final_df['balls_left'] = final_df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
final_df['crr'] = round((final_df['current_score']*6)/final_df['balls_bowled'],2)

# %%
final_df
# Out:
#        match_id  batting_team  bowling_team  runs_x  current_score  \
# 28178       504       England   West Indies       0             66
# 44343       675      Pakistan    Bangladesh       1            130
# 3458         51  South Africa    Bangladesh       1            115
# 37416       604  South Africa   West Indies       1             16
# 59166       879     Sri Lanka   West Indies       1            126
# ...         ...           ...           ...     ...            ...
# 47440       716     Sri Lanka     Australia       0             28
# 3023         36       England   New Zealand       0             24
# 20310       395    Bangladesh      Pakistan       4            111
# 60961       916   New Zealand      Pakistan       1            135
# 55938       829       England  South Africa       0             89
#
#        balls_bowled  wickets_left   crr           city  runs_y  balls_left
# 28178            54             7  7.33       Trinidad     121          66
# ...

# %%
final_df.drop(columns=['balls_bowled'],inplace=True)

# %%
groups = final_df.groupby('match_id')

# %%
match_ids = final_df['match_id'].unique()
last_five = []

for id in match_ids:
    group = groups.get_group(id).sort_index()  # Sort by index to ensure proper rolling
    runs_rolled = group['runs_x'].rolling(window=30).sum()  # Rolling on Series, not full DataFrame
    last_five.extend(runs_rolled.values.tolist())

# %%
final_df['last_five'] = last_five

# %%
final_df
# Out:
#        match_id  batting_team  bowling_team  runs_x  current_score  \
# 28178       504       England   West Indies       0             66
# 44343       675      Pakistan    Bangladesh       1            130
# 3458         51  South Africa    Bangladesh       1            115
# 37416       604  South Africa   West Indies       1             16
# 59166       879     Sri Lanka   West Indies       1            126
# ...         ...           ...           ...     ...            ...
# 47440       716     Sri Lanka     Australia       0             28
# 3023         36       England   New Zealand       0             24
# 20310       395    Bangladesh      Pakistan       4            111
# 60961       916   New Zealand      Pakistan       1            135
# 55938       829       England  South Africa       0             89
#
#        wickets_left   crr           city  runs_y  balls_left  last_five
# 28178             7  7.33       Trinidad     121          66        NaN
# ...

# %%
final_df.dropna(inplace=True)

# %%
final_df
# Out:
#        match_id  batting_team  bowling_team  runs_x  current_score  \
# 51390       786     Sri Lanka  South Africa       1             51
# 5684         77       England     Australia       1            128
# 17162       245         India   New Zealand       1             72
# 49798       747  South Africa     Australia       4             32
# 17234       245         India   New Zealand       2            158
# ...         ...           ...           ...     ...            ...
# 45681       698   New Zealand         India       1            117
# 29177       520     Sri Lanka      Pakistan       0             80
# 8249        100     Sri Lanka         India       0            118
# 19244       308      Pakistan       England       4             47
# 27211       496      Pakistan    Bangladesh       1             67
#
#        wickets_left    crr        city  runs_y  balls_left  last_five
# 51390             8   8.50  Chittagong     165          84       36.0
# ...

# %%
eligible_cities = final_df['city'].value_counts()[final_df['city'].value_counts() > 600].index.tolist()
final_df = final_df[final_df['city'].isin(eligible_cities)]

# %%
X = final_df.drop(columns=['match_id','runs_x','runs_y'])
y = final_df['runs_y']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_test
# Out:
#        batting_team  bowling_team  current_score  wickets_left    crr  \
# 16815   New Zealand       England             21            10  18.00
# 62395       England   West Indies             57             7   6.33
# 40036  South Africa   New Zealand             79             7   7.90
# 56402   New Zealand  South Africa             68             9   9.07
# 20765   West Indies   New Zealand             87             5  10.24
# ...             ...           ...            ...           ...    ...
# 16510   New Zealand       England            116             6   9.16
# 48318  South Africa     Sri Lanka             58             6   4.52
# 25593   New Zealand      Pakistan             41            10   6.47
# 28018     Australia   New Zealand             29            10   9.67
# 50153     Sri Lanka      Pakistan             14             9   4.94
#
#              city  balls_left  last_five
# 16815    Auckland         113       42.0
# 62395     Kolkata          66       44.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_absolute_error

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
# Out:
# C:\Users\MAHAD\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
# ...

# %%
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.949528157711029
# 3.171071434248875

# %%
teams
# Out:
# ['Australia',
#  'India',
#  'Bangladesh',
#  'New Zealand',
#  'South Africa',
#  'England',
#  'West Indies',
#  'Afghanistan',
#  'Pakistan',
#  'Sri Lanka']

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, color='blue', edgecolor='k', alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')  # Perfect prediction line
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.grid(True)
plt.show()

# %%
# Plotting scatter plots between each input feature and the target variable (runs_y)
# This helps visualize how each feature individually correlates with the target.
# It also helps identify patterns, trends, non-linearity, or potential outliers.

for i, col in enumerate(feature_names):
    plt.figure(figsize=(8, 6))
    
    # Check if X_test is a NumPy array or DataFrame and plot accordingly
    plt.scatter(X_test.iloc[:, i], y_test, alpha=0.5)  # X-axis: feature | Y-axis: actual runs
    
    plt.xlabel(col)       # Label for the feature on X-axis
    plt.ylabel('Target (runs_y)')  # Label for the actual runs
    plt.title(f'{col} vs. runs_y')  # Title showing which feature is being plotted
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %%
# Define input and output features
input_features = ['current_score', 'crr', 'wickets_left', 'balls_left']
categorical_features = ['batting_team', 'bowling_team', 'city']
target = 'runs_y'

# Scatter plots for numerical features
for feature in input_features:
    plt.figure(figsize=(10, 4))
    sns.scatterplot(data=final_df, x=feature, y=target, alpha=0.6)
    plt.title(f'{feature} vs {target}')
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Box plots for categorical features
for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=final_df, x=feature, y=target)
    plt.title(f'{feature} vs {target}')
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
